# %%
l1=['Account Number','Account #',
 'Acc #',
 'A/c No.',
 'Account No.',
 'Acc No.',
 'A/c Num.',
 'Account Num.',
 'Acc Num.',
 'A/c #',
 'Acct #',
 'Acct No.',
 'Acct Num.',
 'Acct #',
 'Acct. #',
 'Acct. No.',
 'Acct. Num.',
 'Acct.#',
 'Accnt #',
 'Accnt No.',
 'Accnt Num.',
 'Accnt #',
 'Accnt. #',
 'Accnt. No.',
 'Accnt. Num.',
 'Ac. #',
 'Acct.',
 'Acct. No.',
 'Acct. Num.',
 'Acct.#',
 'Acctno.',
 'Acctnum.',
 'Accno.',
 'Accnum.',
 'A/n #',
 'An #',
 'An No.',
 'An Num.',
 'An#',
 'Acn #',
 'Acn No.',
 'Acn Num.',
 'Acn#',
 'Accntno.',
 'Accntnum.',
 'Acctnumber',
 'Account number',
 'Accountno.',
 'Accountnum.',
 'Acctn.',
 'Acctnumb.',
 'Accnumb.',
 'Acctnbr.',
 'Acctnumbr.',
 'Acntr.',
 'Acntnbr.',
 'Accnbr.',
 'Accnumbr.',
 'Accntnbr.',
 'Accntnumbr.',
 'Acccount #',
 'Acccount No.',
 'Acccount Num.',
 'Acccount#',
 'Accouunt #',
 'Accouunt No.',
 'Accouunt Num.',
 'Accouunt#',
 'Acctt #',
 'Acctt No.',
 'Acctt#',
 'Accntt #',
 'Accntt No.',
 'Accntt Num.',
 'Accntt#',
 'Accntno:',
 'Accntnum:',
 'Account#:',
 'AccountNo:',
 'AccountNum:',
 'Acc#:',
 'AccNo:',
 'AccNum:',
 'A/C :',
 'Acct. #:',
 'Acct. No.:',
 'Acct. Num.:',
 'Acct#:',
 'AcctNo:',
 'AcctNum:',
 'Acn#:',
 'AcnNo:',
 'Accnt#:',
 'AccntNo:',
 'AccntNum:',
 'Account',
 'A/c',
 'Acc.',
 'Acct.',
 'Account#',
 'Acc#',
 'A/C',
 'Acct. #',
 'Acct. No.',
 'Acct. Num.',
 'Acct#',
'Credit Account',
   'Debit Account','Checking Account',]

# %%
l2=['1234 5678',
 '123-456-78',
 '12-3456-78',
 '1234-5678',
 '123.45.67-8',
 '123 45 67-8',
 '12-34567-8',
 '15759413632',
 '    2441207446738',
 '3999395113423',
 '4949559221537',
 '5141411974157',
 '62544702',
 '11651888     ',
 '16759999',
 '79293461',
 '42882598',
 '18751594',
 '37830627',
 '61425857',
 '98717954',
 '96368309      ',
 '1234 5678',
 '123-456-78',
 '12-3456-78',
 '1234-5678',
 '   123.45.67-8',
 '123 45 67-8',
 '12-34567-8',
 '15759413632',
 '2441207446738',
 '3999395113423',
 '4949559221537',
 '5141411974157',
 '62544702',
 '11651888',
 '16759999',
 '79293461',
 '42882598',
 '18751594',
 '37830627',
 '61425857',
 '98717954',
 '96368309',
 '1234 5678',
 '123-456-78',
 '12-3456-78',
 '1234-5678',
 '123.45.67-8',
 '123 45 67-8',
 '12-34567-8',
 '15759413632',
 '2441207446738',
 '3999395113423',
 '4949559221537',
 '5141411974157',
 '62544702',
 '11651888',
 '16759999',
 '79293461',
 '42882598',
 '18751594',
 '37830627',
 '61425857',
 '98717954',
 '96368309',
 '1234 5678',
 '123-456-78',
 '12-3456-78',
 '1234-5678',
 '123.45.67-8',
 '123 45 67-8',
 '12-34567-8',
 '15759413632',
 '2441207446738',
 '3999395113423',
 '4949559221537',
 '5141411974157',
 '62544702',
 '11651888',
 '16759999',
 '79293461',
 '42882598',
 '18751594',
 '37830627',
 '61425857',
 '98717954',
 '96368309',
 '1234 5678',
 '123-456-78',
 '12-3456-78',
 '1234-5678',
 '123.45.67-8',
 '123 45 67-8',
 '12-34567-8',
 '15759413632',
 '2441207446738',
 '3999395113423',
 '4949559221537',
 '5141411974157',
 '62544702',
 '11651888',''
 '16759999',
 '79293461',
 '42882598',
 '18751594']

# %%
l3=['Account Number   1234 5678',
 'Account #   123-456-78',
 'Acc #   12-3456-78',
 'A/c No.   1234-5678',
 'Account No.   123.45.67-8',
 'Acc No.   123 45 67-8',
 'A/c Num.   12-34567-8',
 'Account Num.   15759413632',
 'Acc Num.       2441207446738',
 'A/c #   3999395113423',
 'Acct #   4949559221537',
 'Acct No.   5141411974157',
 'Acct Num.   62544702',
 'Acct #   11651888     ',
 'Acct. #   16759999',
 'Acct. No.   79293461',
 'Acct. Num.   42882598',
 'Acct.#   18751594',
 'Accnt #   37830627',
 'Accnt No.   61425857',
 'Accnt Num.   98717954',
 'Accnt #   96368309      ',
 'Accnt. #   1234 5678',
 'Accnt. No.   123-456-78',
 'Accnt. Num.   12-3456-78',
 'Ac. #   1234-5678',
 'Acct.      123.45.67-8',
 'Acct. No.   123 45 67-8',
 'Acct. Num.   12-34567-8',
 'Acct.#   15759413632',
 'Acctno.   2441207446738',
 'Acctnum.   3999395113423',
 'Accno.   4949559221537',
 'Accnum.   5141411974157',
 'A/n #   62544702',
 'An #   11651888',
 'An No.   16759999',
 'An Num.   79293461',
 'An#   42882598',
 'Acn #   18751594',
 'Acn No.   37830627',
 'Acn Num.   61425857',
 'Acn#   98717954',
 'Accntno.   96368309',
 'Accntnum.   1234 5678',
 'Acctnumber   123-456-78',
 'Account number   12-3456-78',
 'Accountno.   1234-5678',
 'Accountnum.   123.45.67-8',
 'Acctn.   123 45 67-8',
 'Acctnumb.   12-34567-8',
 'Accnumb.   15759413632',
 'Acctnbr.   2441207446738',
 'Acctnumbr.   3999395113423',
 'Acntr.   4949559221537',
 'Acntnbr.   5141411974157',
 'Accnbr.   62544702',
 'Accnumbr.   11651888',
 'Accntnbr.   16759999',
 'Accntnumbr.   79293461',
 'Acccount #   42882598',
 'Acccount No.   18751594',
 'Acccount Num.   37830627',
 'Acccount#   61425857',
 'Accouunt #   98717954',
 'Accouunt No.   96368309',
 'Accouunt Num.   1234 5678',
 'Accouunt#   123-456-78',
 'Acctt #   12-3456-78',
 'Acctt No.   1234-5678',
 'Acctt#   123.45.67-8',
 'Accntt #   123 45 67-8',
 'Accntt No.   12-34567-8',
 'Accntt Num.   15759413632',
 'Accntt#   2441207446738',
 'Accntno:   3999395113423',
 'Accntnum:   4949559221537',
 'Account#:   5141411974157',
 'AccountNo:   62544702',
 'AccountNum:   11651888',
 'Acc#:   16759999',
 'AccNo:   79293461',
 'AccNum:   42882598',
 'A/C :   18751594',
 'Acct. #:   37830627',
 'Acct. No.:   61425857',
 'Acct. Num.:   98717954',
 'Acct#:   96368309',
 'AcctNo:   1234 5678',
 'AcctNum:   123-456-78',
 'Acn#:   12-3456-78',
 'AcnNo:   1234-5678',
 'Accnt#:   123.45.67-8',
 'AccntNo:   123 45 67-8',
 'AccntNum:   12-34567-8',
 'Account   15759413632',
 'A/c   2441207446738',
 'Acc.   3999395113423',
 'Acct.   4949559221537',
 'Account#   5141411974157',
 'Acc#   62544702',
 'A/C   11651888',
 'Acct. #   16759999',
 'Acct. No.   79293461',
 'Acct. Num.   42882598',
 'Acct#   18751594']

# %%
from PIL import Image, ImageDraw, ImageFont

# Open the image file
image = Image.open('pic1.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1152x648 at 0x20302FDD948>

# %%
for i in range(len(l1)):
    image = Image.open('pic1.jpg')
    font = ImageFont.truetype("arial.ttf", 18)

    #template = Image.open("template.png")
    draw = ImageDraw.Draw(image)
    draw.text((550, 120), l1[i], font=font, fill='black')
    draw.text((550, 155), l2[i], font=font, fill='black')
    draw.text((70, 120), l3[len(l1)-i-1], font=font, fill='black')
    new_folder = r'C:\Users\vikra\OneDrive\Documents\important__\tempgen\tempate-card-generator-master\Scotia\pic1gen'
    new_filename = 'imga'+str(i)+'.jpg'
    image.save(f'{new_folder}/{new_filename}')
